# %% [markdown]
# <a href="https://colab.research.google.com/github/snakecharu/Charusnajeev/blob/main/Day_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Tuples**

# %%
#list[]
#dictionary{}
#tuple()
#set{}

# %% [markdown]
# **creating a tuple**

# %%
tuple=(1,2,3)
print(tuple)
# Out:
# (1, 2, 3)

# %%
print(tuple[0])
# Out:
# 1

# %% [markdown]
# **Tuple Operations**

# %%
t1=(1,2,3)
t2=("A","B","C")
t1+t2
# Out:
# (1, 2, 3, 'A', 'B', 'C')

# %%
t3=(1,)
t3*5
# Out:
# (1, 1, 1, 1, 1)

# %% [markdown]
# **tuple vs set**

# %%
#tuple-immutable(!add,!remove...)memory low
#List-mutable(add,remove..)memory high

# %% [markdown]
# **Sets**

# %%
s={1,1,2}
print(s)
# Out:
# {1, 2}

# %% [markdown]
# **Set Operations**

# %%
s1={1,2,3}
s2={1,2,4}
s1.union(s2)
# Out:
# {1, 2, 3, 4}

# %%
s1.intersection(s2)
# Out:
# {1, 2}

# %%
s1.difference(s2)
# Out:
# {3}

# %%
s2.difference(s1)
# Out:
# {4}
