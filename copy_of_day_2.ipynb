# %% [markdown]
# <a href="https://colab.research.google.com/github/snakecharu/Charusnajeev/blob/main/copy_of_day_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Data Types**

# %%
#int-Integer(infinity.......-1,0,1........+infinity)
#float-Double(1.0,10.0)
#str-String("a","apple","i am charu")

# %%
#Data types-a(variable),10(value)

# %%
a=10
b=20
c=30
print(c)
# Out:
# 30

# %%
charu=5
mathi=15
devi=25
print(charu)
# Out:
# 5

# %%
x,y,z=10,20,30
print(x,y,z)
# Out:
# 10 20 30
