# %% [markdown]
# <a href="https://colab.research.google.com/github/snakecharu/Charusnajeev/blob/main/Day_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Strings in Pyhton**

# %% [markdown]
# **Creating Strings**

# %%
single_quote='charu'
double_quote="charu"
triple_quote='''charu
mathi
devi'''
print(single_quote)
print(double_quote)
print(triple_quote)
# Out:
# charu
# charu
# charu
# mathi
# devi

# %%
#multiline strings
multiy_quote='''
this is a first line
this is a second line
'''

# %% [markdown]
# **Accessing Strings**

# %%
s="charu"
s[0]
s[1]
s[2]

# %% [markdown]
# **negative Indexing**

# %%
s="charu"
s[-1]
s[-2]

# %% [markdown]
# **Counting characters in a string**

# %%
print(len(s))

# %% [markdown]
# **Slicing a String**

# %%
s[1:3]
s[:4]
s[1:]

# %% [markdown]
# **String concatenation**

# %%
"snake"+"Charu"
# Out:
# 'snakeCharu'

# %% [markdown]
# **String Repetition**

# %%
"ha"*5
# Out:
# 'hahahahaha'

# %% [markdown]
# **String Length**

# %%
s="Charu"
len(s)
# Out:
# 5

# %% [markdown]
# **Checking Substrings**

# %%
#substring-String which is a part of a main string
s="Snake Lover"
print("Snake"in s)
# Out:
# True

# %%
s="Snake Lover"
print("Son"in s)
# Out:
# False

# %% [markdown]
# **String Methods/Functions**

# %%
#join,strip,split this are available in string methods
name="charu"
name.upper()
# Out:
# 'CHARU'

# %% [markdown]
# **String Formating F-string**

# %%
name="charu"
print(f"My name is {name}!")
# Out:
# My name is charu!
