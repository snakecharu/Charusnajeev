# %% [markdown]
# <a href="https://colab.research.google.com/github/snakecharu/Charusnajeev/blob/main/Day_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Error Handling**

# %% [markdown]
# **Syntax Error**

# %%
print("hello"
# Out:
#   File "/tmp/ipython-input-1-4227803888.py", line 1
#     print("hello"
#                  ^
# SyntaxError: incomplete input

# %% [markdown]
# **Index Error**

# %%
l=[0,1]
l[2]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-2-1520244245.py in <cell line: 0>()
#       1 l=[0,1]
# ----> 2 l[2]
#
# IndexError: list index out of range

# %% [markdown]
# **Type Error**

# %%
2+"hello"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-4-1903837953.py in <cell line: 0>()
# ----> 1 2+"hello"
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# **key error**

# %%
d1={"k1":"1"}
d1["k2"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-18-4237214872.py in <cell line: 0>()
#       1 d1={"k1":"1"}
# ----> 2 d1["k2"]
#
# KeyError: 'k2'

# %% [markdown]
# **name error**

# %%
y
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-19-3563912222.py in <cell line: 0>()
# ----> 1 y
#
# NameError: name 'y' is not defined

# %% [markdown]
# **Zero Division Error**

# %%
10/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipython-input-20-530406163.py in <cell line: 0>()
# ----> 1 10/0
#
# ZeroDivisionError: division by zero

# %% [markdown]
# **handle zerodivision error**

# %% [markdown]
# **Value error**

# %%
v=int("charu")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-29-2597377631.py in <cell line: 0>()
# ----> 1 v=int("charu")
#
# ValueError: invalid literal for int() with base 10: 'charu'

# %%
#try except
try:
  10/0
except ZeroDivisionError:
  print("error")
# Out:
# error

# %%
10/0

y=2+3
print(y)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipython-input-23-2631935206.py in <cell line: 0>()
# ----> 1 10/0
#       2
#       3 y=2+3
#       4 print(y)
#
# ZeroDivisionError: division by zero

# %%
try:
  10/0
except ZeroDivisionError:
  print("error")
y=2+3
print(y)
# Out:
# error
# 5

# %% [markdown]
# **handle value error**

# %%
try:
  v=int("charu")
except ValueError:
  print("error")
# Out:
# error
